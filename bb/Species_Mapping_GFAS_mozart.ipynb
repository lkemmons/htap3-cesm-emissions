# %%
sys.path.insert(0,'/glade/u/home/emmons/python/')
import numpy as np
import xarray as xr
import esmpy as ESMF
import glob
import datetime
import os
from netCDF4 import Dataset
from functions.array.chk import chk
from functions.Plot_2D import Plot_2D
from functions.Calc_Emis import Calc_Emis_T
from functions.Regridding_ESMF import Add_bounds, Regridding
from functions.analysis.Species_Mapping import sp_map
from functions.io.get_sp import get_sp
import multiprocessing, psutil
from functions.io.NetCDF_IO import nccopy

# %%
ssss = sp_map( 'species_mapping_GFAS_mozart.dat', verbose=True, keep_sector=True, print_user_nl_cam=True, nc_file_format='NETCDF4', day_of_each_month=15 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ssss = sp_map( 'species_mapping_GFAS_mozart.dat', verbose=True, keep_sector=True, print_user_nl_cam=True, nc_file_format='NETCDF4', day_of_each_month=15 )
#
# File ~/python/functions/analysis/Species_Mapping.py:111, in sp_map.__init__(self, mapping_file, nc_file_format, print_user_nl_cam, keep_sector, read_file_only, date_array, day_of_each_month, ignore_warning, verbose)
#     108     self.srf_emis_specifier = "srf_emis_specifier = "
#     110 # Read species mapping file
# --> 111 self.read_mapping_file()
#     113 # Remapping
#     114 if not read_file_only:
#
# File ~/python/functions/analysis/Species_Mapping.py:196, in sp_map.read_mapping_file(self)
#     194 self.eq_species[sp_tmp].append( tmp[2+int(ei*2)].split('*')[-1] )
#     195 pos_sp_border = tmp[2+int(ei*2)].rfind('*')
# ...

# %%
nccopy( ssss.Destination_files.values() )
