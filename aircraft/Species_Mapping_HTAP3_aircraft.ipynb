# %%
sys.path.insert(0,'/glade/u/home/emmons/python/')
import numpy as np
import xarray as xr
import esmpy as ESMF
import glob
import datetime
import os
from netCDF4 import Dataset
from functions.array.chk import chk
from functions.Plot_2D import Plot_2D
from functions.Calc_Emis import Calc_Emis_T
from functions.Regridding_ESMF import Add_bounds, Regridding
from functions.analysis.Species_Mapping import sp_map
from functions.io.get_sp import get_sp
import multiprocessing, psutil
from functions.io.NetCDF_IO import nccopy

# %%
ssss = sp_map( 'species_mapping_HTAP3_aircraft.dat', verbose=True, print_user_nl_cam=True, nc_file_format='NETCDF4', day_of_each_month=15 )
# Out:
# Processing:  NO2 2025-11-26 16:20:54.013194
# Warning: some aircraft emissions have a unit of xx (c)m-3 s-1
#          here we assume a unit of xx (c)m-2 s-1
#          i.e. divide each layer emission by vertical depth
# Processing:  SO2 2025-11-26 16:20:57.237566
# Warning: some aircraft emissions have a unit of xx (c)m-3 s-1
#          here we assume a unit of xx (c)m-2 s-1
#          i.e. divide each layer emission by vertical depth
# Processing:  CO 2025-11-26 16:21:00.409683
# Warning: some aircraft emissions have a unit of xx (c)m-3 s-1
#          here we assume a unit of xx (c)m-2 s-1
#          i.e. divide each layer emission by vertical depth
# Processing:  bc_a4 2025-11-26 16:21:03.748497
# Warning: some aircraft emissions have a unit of xx (c)m-3 s-1
#          here we assume a unit of xx (c)m-2 s-1
#          i.e. divide each layer emission by vertical depth
# Processing:  num_bc_a4 2025-11-26 16:21:06.428975
# Warning: some aircraft emissions have a unit of xx (c)m-3 s-1
#          here we assume a unit of xx (c)m-2 s-1
#          i.e. divide each layer emission by vertical depth
# Printing text for the use of user_nl_cam:
# Text is also saved in user_nl_cam_from_sp_map_c20251126
# ext_frc_specifier = 'NO2 -> /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_NO2_moleccm3s_c20251126.nc',
#                     'SO2 -> /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_SO2_moleccm3s_c20251126.nc',
#                     'CO -> /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_CO_moleccm3s_c20251126.nc',
#                     'bc_a4 -> /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_bc_a4_moleccm3s_c20251126.nc',
#                     'num_a4 -> /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_num_bc_a4_moleccm3s_c20251126.nc',
#
# srf_emis_specifier =

# %%
nccopy( ssss.Destination_files.values() )
# Out:
# processing:  /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_NO2_moleccm3s_c20251126.nc 2025-11-26 16:21:21.653658
# processing:  /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_SO2_moleccm3s_c20251126.nc 2025-11-26 16:21:28.386147
# processing:  /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_CO_moleccm3s_c20251126.nc 2025-11-26 16:21:33.927718
# processing:  /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_bc_a4_moleccm3s_c20251126.nc 2025-11-26 16:21:39.158313
# processing:  /glade/campaign/acom/acom-weather/emmons/HTAP3/emissions/aircraft/f09/HTAP3-aircraft_200001-210012_NAEUAS01_ne30x8_num_bc_a4_moleccm3s_c20251126.nc 2025-11-26 16:21:44.414951
